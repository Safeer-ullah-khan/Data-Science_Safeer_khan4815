# %%
import numpy as np

# %%
a=np.array([1,2,3])

# %%
print(a)
# Out:
# [1 2 3]

# %%
#normaliztion
arr=np.linspace(0,1,8)
arr
# Out:
# array([0.        , 0.14285714, 0.28571429, 0.42857143, 0.57142857,
#        0.71428571, 0.85714286, 1.        ])
