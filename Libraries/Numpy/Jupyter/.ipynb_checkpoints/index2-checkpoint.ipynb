# %%
print("hello")
# Out:
# hello

# %%
print("My name is safeer")
# Out:
# My name is safeer

# %%
def grade():
    grade="A"
    print(f"The grade is {grade}")

# %%
grade()
# Out:
# The grade is A
