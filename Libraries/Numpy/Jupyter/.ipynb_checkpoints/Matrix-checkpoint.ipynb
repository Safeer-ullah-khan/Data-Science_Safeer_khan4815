# %%
import numpy as np

# %%
arr=np.arange(1,5).reshape(2,2)
arr2=np.arange(5,9).reshape(2,2)

# %%
# Matrix multiplication where is first row of matrix1 multiplay with first column of second matrix and so on
arr @ arr2
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
np.dot(arr,arr2)
# Out:
# array([[19, 22],
#        [43, 50]])
