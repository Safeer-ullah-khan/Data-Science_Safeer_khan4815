# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# """"Pivot Tables""""

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    908     59   John  January      Q1
# 1  2023-01-02       B   West    973     41   Mary  January      Q1
# 2  2023-01-03       C  North    484     62    Bob  January      Q1
# 3  2023-01-04       D  South    169     92  Alice  January      Q1
# 4  2023-01-05       A   East    995     73   John  January      Q1
# 5  2023-01-06       B   West    708     16   Mary  January      Q1
# 6  2023-01-07       C  North    783     79    Bob  January      Q1
# 7  2023-01-08       D  South    429     17  Alice  January      Q1
# 8  2023-01-09       A   East    925     26   John  January      Q1
# 9  2023-01-10       B   West    638     53   Mary  January      Q1
# 10 2023-01-11       C  North    642     14    Bob  January      Q1
# 11 2023-01-12       D  South    660     41  Alice  January      Q1
# 12 2023-01-13       A   East    567     38   John  January      Q1
# ...

# %%
pd.pivot_table(df,values='Sales',index='Product',columns='Region',aggfunc='count')
#used for the aggregation function on the tables
# Out:
# Region   East  North  South  West
# Product
# A         5.0    NaN    NaN   NaN
# B         NaN    NaN    NaN   5.0
# C         NaN    5.0    NaN   NaN
# D         NaN    NaN    5.0   NaN

# %%
pd.pivot_table(df,values='Units',index='Product',columns='Region',aggfunc='mean')
# Out:
# Region   East  North  South  West
# Product
# A        52.4    NaN    NaN   NaN
# B         NaN    NaN    NaN  41.4
# C         NaN   58.8    NaN   NaN
# D         NaN    NaN   67.6   NaN

# %%
pd.pivot_table(df,values=['Sales','Units'],index='Product',columns='Region',aggfunc='mean')
# Out:
#          Sales                      Units
# Region    East  North  South   West  East North South  West
# Product
# A        780.4    NaN    NaN    NaN  52.4   NaN   NaN   NaN
# B          NaN    NaN    NaN  530.6   NaN   NaN   NaN  41.4
# C          NaN  598.8    NaN    NaN   NaN  58.8   NaN   NaN
# D          NaN    NaN  483.8    NaN   NaN   NaN  67.6   NaN

# %%
pd.pivot_table(df,values='Units',index=['Product','Rep'],columns='Region',aggfunc='mean')
# Out:
# Region         East  North  South  West
# Product Rep
# A       John   52.4    NaN    NaN   NaN
# B       Mary    NaN    NaN    NaN  41.4
# C       Bob     NaN   58.8    NaN   NaN
# D       Alice   NaN    NaN   67.6   NaN

# %% [markdown]
# """Cross Tables"""

# %%
pd.crosstab(df['Product'],df['Region'])# used for counting the values
# Out:
# Region   East  North  South  West
# Product
# A           5      0      0     0
# B           0      0      0     5
# C           0      5      0     0
# D           0      0      5     0
