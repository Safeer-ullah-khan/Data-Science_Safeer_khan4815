# %%
import numpy as np

# %%
import pandas as pd

# %%
labels=['a','b','c']
My_list=[10,20,30]
arr=np.array([10,20,30])#only one dimentional array should be pass not  two dimentional array
dictionary={1:10,2:20,3:30}

# %%
Se=pd.Series(My_list)
print(Se)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
Se=pd.Series(My_list, index=labels)
print(Se)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
Se=pd.Series(dictionary)
print(Se)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64
