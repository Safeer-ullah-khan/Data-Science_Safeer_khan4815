# %%
import numpy as np
import pandas as pd

# %%
data={
    'Name':['safeer','ahmad','tahir'],
    'Age':[21,20,22],
    'city':['DIKhan','Islamabad','karachi'],
    'salary':[20000,40000,30000]
}

# %%
pd.DataFrame(data)
# Out:
#      Name  Age       city  salary
# 0  safeer   21     DIKhan   20000
# 1   ahmad   20  Islamabad   40000
# 2   tahir   22    karachi   30000

# %%
#creating dataframes through list
data_list=[['safeer',21,'DIKhan',20000], 
           ['ahmad',20,'Islambad',40000],
           ['tahir',22,'karachi',30000]
        ]
column=['Name','Age','City','Salary']

# %%
df=pd.DataFrame(data_list,columns=column)
print(df)
# Out:
#      Name  Age      City  Salary
# 0  safeer   21    DIKhan   20000
# 1   ahmad   20  Islambad   40000
# 2   tahir   22   karachi   30000

# %%
print(df.loc[0])#it will return one or more specific rows
# Out:
# Name      safeer
# Age           21
# City      DIKhan
# Salary     20000
# Name: 0, dtype: object

# %%
#selecting one column
df['Name']
# Out:
# 0    safeer
# 1     ahmad
# 2     tahir
# Name: Name, dtype: str

# %%
#selecting two columns
df[['Name','City']]
# Out:
#      Name      City
# 0  safeer    DIKhan
# 1   ahmad  Islambad
# 2   tahir   karachi

# %%
#adding a new column
df['Designation']=['Developer','Manager','Tester']

# %%
df
# Out:
#      Name  Age      City  Salary Designation
# 0  safeer   21    DIKhan   20000   Developer
# 1   ahmad   20  Islambad   40000     Manager
# 2   tahir   22   karachi   30000      Tester

# %%
#removing column from data set
df.drop('Designation',axis=1)
# Out:
#      Name  Age      City  Salary
# 0  safeer   21    DIKhan   20000
# 1   ahmad   20  Islambad   40000
# 2   tahir   22   karachi   30000

# %%
df.drop('Designation',axis=1,inplace=True)#remove the column from data set permanently

# %%
df
# Out:
#      Name  Age      City  Salary
# 0  safeer   21    DIKhan   20000
# 1   ahmad   20  Islambad   40000
# 2   tahir   22   karachi   30000

# %%
#removing multiple columns from data set
df.drop(['Age','City'],axis=1)
# Out:
#      Name  Salary
# 0  safeer   20000
# 1   ahmad   40000
# 2   tahir   30000

# %%
#removing row from the table
df.drop(1,axis=0)
# Out:
#      Name  Age     City  Salary
# 0  safeer   21   DIKhan   20000
# 2   tahir   22  karachi   30000

# %% [markdown]
#  ``` Selection Of rows and ```

# %%
#selecting subsets of rows and columns
df.loc[[0,2]][['City','Salary']]
# Out:
#       City  Salary
# 0   DIKhan   20000
# 2  karachi   30000

# %%
#conditional selection
df[(df['Age']<22) & (df['City']=='DIKhan')]
# Out:
#      Name  Age    City  Salary
# 0  safeer   21  DIKhan   20000
