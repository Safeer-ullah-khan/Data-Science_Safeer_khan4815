# %%
import numpy as np

# %%
arr=np.array([20, 21, 22, 22, 23, 24, 25, 26, 200])

# %%
Q1=np.percentile(arr,25)
Q1
# Out:
# np.float64(22.0)

# %%
Q3=np.percentile(arr,75)
Q3
# Out:
# np.float64(25.0)

# %%
IQR=Q3-Q1

# %%
UF=Q3 +(1.5 * IQR)

# %%
LF=Q1 - (1.5 * IQR)

# %%
updated_list=[]
for i in arr:
    if i >=LF and i<=UF:
        updated_list.append(i)

# %%
arr2=np.array(updated_list)

# %%
arr2
# Out:
# array([20, 21, 22, 22, 23, 24, 25, 26])

# %%
import seaborn as sns

# %%
outlier=sns.boxplot(y=arr)
outlier
# Out:
# <Axes: >

# %%
fixed=sns.boxplot(y=arr2)
